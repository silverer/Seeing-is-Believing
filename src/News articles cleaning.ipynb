# %%
import data_io
import pandas as pd
import numpy as np
import regex as re
import utils as u

# %% [markdown]
# Read in manually coded datasets

# %%
schools = ['Princeton', 'Harvard', 'Yale', 'Columbia','MIT']

dfs = {}
for s in schools:
    dfs[s] = pd.read_excel(data_io.DATA+f"{s.lower()}_data_2019_formatted.xlsx")

# %%
for k in dfs.keys():
    print(len(dfs[k]))
    dfs[k] = dfs[k].loc[1:,:]
    print(len(dfs[k]))
# Out:
# 229
# 228
# 196
# 195
# 135
# 134
# 164
# 163
# 182
# 181

# %%
image_cols = ['article_id','first_researcher_pictured',
       'num_male_researchers_pictured', 'num_female_researchers_pictured',
       'num_other_researchers_pictured', 'num_women_pictured',
       'num_men_pictured', 'num_other_people_pictured']
article_text_cols = ['article_id','gender_first_researcher', 'num_women_mentioned',
       'num_men_mentioned', 'num_others_mentioned']

# %%
def check_completeness_text(df):
    art_df = df.copy()
    no_dups = art_df.dropna(subset = ['article_id'])
    no_dups = art_df.drop_duplicates(subset = ['article_id'], keep = 'first')
    no_gender = no_dups[pd.isnull(no_dups['gender_first_researcher'])]
    return no_gender

def check_completeness_photos(df):
    art_df = df.copy()
    images_only = art_df[image_cols]
    no_gender = images_only[pd.isnull(images_only['first_researcher_pictured'])]
    return no_gender

# %%
incomplete_text = {}
incomplete_photos = {}

# %%
for k in dfs.keys():
    dfs[k] = dfs[k].reset_index(drop = True)
    temp = check_completeness_text(dfs[k])
    incomplete_text[k] = temp
    print(k, ' number w incomplete text coding: ')
    print(len(temp))
    temp = check_completeness_photos(dfs[k])
    incomplete_photos[k] = temp
    print(k, ' number w incomplete image coding: ')
    print(len(temp))
# Out:
# Princeton  number w incomplete text coding:
# 0
# Princeton  number w incomplete image coding:
# 0
# Harvard  number w incomplete text coding:
# 0
# Harvard  number w incomplete image coding:
# 0
# Yale  number w incomplete text coding:
# 1
# Yale  number w incomplete image coding:
# 1
# Columbia  number w incomplete text coding:
# 0
# Columbia  number w incomplete image coding:
# 2
# MIT  number w incomplete text coding:
# 0
# MIT  number w incomplete image coding:
# 0

# %% [markdown]
# Look at incomplete articles:

# %%
yale = dfs["Yale"]
yale[yale['article_id'] == incomplete_text['Yale'].reset_index().loc[0, 'article_id']]
# Out:
#    article_id                                      article_title  \
# 31   yale_220  Creativity in motion: how Yale engineering put...
#
#                                          article_link article_text  \
# 31  https://news.yale.edu/in-focus/creativity-moti...          NaN
#
#    article_date gender_first_researcher num_women_mentioned num_men_mentioned  \
# 31      NO DATE                     NaN                   0                 1
#
#    num_others_mentioned image_alt_text  ...  \
# 31                    0            NaN  ...
#
#                                    comments image_location image_links  \
# 31  no researchers mentioned in the article            NaN         NaN
#
#    article_date_scrape                               article_title_scrape  \
# 31     August 28, 2019  Creativity in motion: how Yale engineering put...
#
#                                          url_redirect PAGE_TYPE source in_og  \
# 31  https://news.yale.edu/in-focus/creativity-moti...   article    old   NaN
#
#    new_article_text
# 31              NaN
#
# [1 rows x 30 columns]

# %%
columbia = dfs['Columbia']
#2 pictures didn't save bc they don't render on the webpage
columbia.loc[pd.isnull(columbia['first_researcher_pictured']),:]
# Out:
#       article_id article_title article_link article_date new_article_text  \
# 27  columbia_124           NaN          NaN          NaN              NaN
# 75  columbia_160           NaN          NaN          NaN              NaN
#
#    gender_first_researcher num_women_mentioned num_men_mentioned  \
# 27                     NaN                 NaN               NaN
# 75                     NaN                 NaN               NaN
#
#    num_others_mentioned image_alt_text  ... num_men_pictured  \
# 27                  NaN    fish stocks  ...              NaN
# 75                  NaN            NaN  ...              NaN
#
#    num_women_pictured num_other_people_pictured rater_initials  \
# 27                NaN                       NaN            NaN
# 75                NaN                       NaN            NaN
#
#                           comments  \
# 27                             NaN
# 75  can't open the file on ricebox
#
#                                        image_location article_date_scrape  \
# 27  /Users/elisabethsilver/Box/SIB/photos/columbia...                 NaN
# 75  /Users/elisabethsilver/Box/SIB/photos/columbia...                 NaN
#
#    article_title_scrape new_article_text.1 article_text
# 27                  NaN                NaN          NaN
# 75                  NaN                NaN          NaN
#
# [2 rows x 27 columns]

# %%
def clean_dataset(df_orig, uni = None):
    df = df_orig.copy()
    row_counts = pd.DataFrame(df['article_id'].value_counts()).reset_index()
    if 'new_article_text' in df.columns.to_list():
        df = df.drop(columns = ['article_text'])
        df = df.rename(columns = {'new_article_text': 'article_text'})
    row_counts.columns = ['article_id', 'rows']
    row_counts = dict(zip(row_counts['article_id'].to_list(),
                         row_counts['rows'].to_list()))
    df['num_pics'] = df['article_id'].map(row_counts)
    gender_dict = {0: 'Unclear',
                  1: 'Man',
                  2: 'Woman'}
    df['gender_first_researcher_text'] = df['gender_first_researcher'].map(gender_dict)
    grpd = df.groupby(['article_id'])
    num_first_res_pic = {}
    num_fres_pic = {}
    num_mres_pic = {}
    num_women_pic = {}
    num_men_pic = {}
    for name, grp in grpd:
        num_first_res_pic[name] = sum(grp['first_researcher_pictured'])
        num_fres_pic[name] = sum(grp['num_female_researchers_pictured'])
        num_mres_pic[name] = sum(grp['num_male_researchers_pictured'])
        num_women_pic[name] = sum(grp['num_women_pictured'])
        num_men_pic[name] = sum(grp['num_men_pictured'])
    
    df['num_men_mentioned'] = df['num_men_mentioned'].astype(float)
    df['num_women_mentioned'] = df['num_women_mentioned'].astype(float)
    df['num_first_res_pics'] = df['article_id'].map(num_first_res_pic).astype(int)
    df['num_female_res_pics'] = df['article_id'].map(num_fres_pic).astype(int)
    df['num_male_res_pics'] = df['article_id'].map(num_mres_pic).astype(int)
    df['total_men_pics'] = df['article_id'].map(num_men_pic).astype(int)
    df['total_women_pics'] = df['article_id'].map(num_women_pic).astype(int)
    df['total_people_mentioned'] = (df['num_women_mentioned'] + df['num_men_mentioned'] + 
                                    df['num_others_mentioned'])
    
    if uni:
        df['uni'] = uni
    return df

# %% [markdown]
# Remove articles that failed to scrape

# %%
yale = dfs['Yale']
#One article failed to scrape, remove it
yale = yale[yale['article_id'] != incomplete_text['Yale'].reset_index().loc[0, 'article_id']]

# %%
columbia = dfs['Columbia']
#2 pictures didn't save bc they don't render on the webpage
columbia = columbia.dropna(subset=['first_researcher_pictured'])
columbia = columbia.reset_index(drop =True)

# %%
yale = clean_dataset(yale, uni = 'yale')
columbia = clean_dataset(columbia, uni = 'columbia')
mit = clean_dataset(dfs['MIT'], uni = 'mit')
princeton = clean_dataset(dfs['Princeton'], uni = 'princeton')
harvard = clean_dataset(dfs['Harvard'], uni = 'harvard')

# %%
df = pd.concat([mit, princeton, yale, harvard, columbia], ignore_index=True)

# %%
df.dropna(subset=['article_text'])['num_men_mentioned'].isnull().sum()
# Out:
# 0

# %%
tmp = df.dropna(subset=['article_link', 'gender_first_researcher_text'])
tmp
# Out:
#        article_id                                      article_title  \
# 0        mit_1452  Enhanced NMR reveals chemical structures in a ...
# 1        mit_1266  How biomarkers can record and reconstruct clim...
# 2         mit_666  From one brain scan, more information for medi...
# 3         mit_549  New approach suggests path to emissions-free c...
# 5         mit_673  Researchers solve mystery of how gas bubbles f...
# ..            ...                                                ...
# 889  columbia_249  Climate Change Tipping Point Could Be Coming S...
# 890  columbia_252  Climate-Driven Fires Could Turn Yellowstone Fo...
# 891  columbia_254  Heating Buildings Leaves a Huge Carbon Footpri...
# 893  columbia_255   Genes on the Move Help Nose Make Sense of Scents
# 894  columbia_256  Scientists Work to Build Climate Change Resili...
#
#                                           article_link        article_date  \
# 0    https://news.mit.edu/2019/nmr-chemical-structu...    January 18, 2019
# 1    https://news.mit.edu/2019/how-biomarkers-recor...    December 4, 2019
# 2    https://news.mit.edu/2019/training-artificial-...       June 19, 2019
# 3    https://news.mit.edu/2019/carbon-dioxide-emiss...  September 16, 2019
# 5    https://news.mit.edu/2019/how-gas-bubbles-form...       June 17, 2019
# ..                                                 ...                 ...
# 889  https://science.fas.columbia.edu/news/climate-...    January 23, 2019
# 890  https://science.fas.columbia.edu/news/climate-...    January 17, 2019
# 891  https://science.fas.columbia.edu/news/heating-...    January 15, 2019
# 893  https://science.fas.columbia.edu/news/genes-on...     January 9, 2019
# 894  https://science.fas.columbia.edu/news/scientis...     January 8, 2019
#
#     gender_first_researcher  num_women_mentioned  num_men_mentioned  \
# 0                         1                  1.0                4.0
# 1                         1                  1.0                2.0
# 2                         2                  1.0                4.0
# 3                         1                  1.0                2.0
# 5                         1                  0.0                4.0
# ..                      ...                  ...                ...
# 889                       1                  1.0                2.0
# 890                       1                  1.0                1.0
# 891                       1                  0.0                1.0
# 893                       1                  0.0                3.0
# 894                       2                  3.0                1.0
#
#     num_others_mentioned                                     image_alt_text  \
# 0                      1  MIT chemists have enhanced the resolution of n...
# 1                      0  The composition and location of rock strata he...
# 2                      0  MIT researchers have developed a system that g...
# 3                      0  In a demonstration of the basic chemical react...
# 5                      0  Series of images from the team’s lab experimen...
# ..                   ...                                                ...
# 889                    0                                                NaN
# 890                    0                                                NaN
# 891                    0                                                NaN
# 893                    0                                                NaN
# 894                    0                                                NaN
#
#                                         image_captions  ...  \
# 0              MIT chemists have enhanced the resol...  ...
# 1              The composition and location of rock...  ...
# 2              MIT researchers have developed a sys...  ...
# 3              In a demonstration of the basic chem...  ...
# 5              Series of images from the team’s lab...  ...
# ..                                                 ...  ...
# 889  Limpopo province in South Africa– a semi-arid ...  ...
# 890  Lead author Winslow Hansen, at one of his stud...  ...
# 891                              Photo: Stephen Downes  ...
# 893  A section of the olfactory epithelium. Cells t...  ...
# 894  Half Moon Caye Natural Monument, part of the M...  ...
#
#     OLD_article_text_w_main_img_caption needs_recode url_redirect PAGE_TYPE  \
# 0                                   NaN          NaN          NaN       NaN
# 1                                   NaN          NaN          NaN       NaN
# 2                                   NaN          NaN          NaN       NaN
# 3                                   NaN          NaN          NaN       NaN
# 5                                   NaN          NaN          NaN       NaN
# ..                                  ...          ...          ...       ...
# 889                                 NaN          NaN          NaN       NaN
# 890                                 NaN          NaN          NaN       NaN
# 891                                 NaN          NaN          NaN       NaN
# 893                                 NaN          NaN          NaN       NaN
# 894                                 NaN          NaN          NaN       NaN
#
#     source in_og article_id.1 recode rater_recode_intials  \
# 0      NaN   NaN          NaN    NaN                  NaN
# 1      NaN   NaN          NaN    NaN                  NaN
# 2      NaN   NaN          NaN    NaN                  NaN
# 3      NaN   NaN          NaN    NaN                  NaN
# 5      NaN   NaN          NaN    NaN                  NaN
# ..     ...   ...          ...    ...                  ...
# 889    NaN   NaN          NaN    NaN                  NaN
# 890    NaN   NaN          NaN    NaN                  NaN
# 891    NaN   NaN          NaN    NaN                  NaN
# 893    NaN   NaN          NaN    NaN                  NaN
# 894    NaN   NaN          NaN    NaN                  NaN
#
#                                     new_article_text.1
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 5                                                  NaN
# ..                                                 ...
# 889  Global carbon emissions reached a record high ...
# 890  Adapted from a news release by Kelly Tyrrell o...
# 891  As winter weather sets in, the heat kicks on i...
# 893  The human nose can distinguish one trillion di...
# 894  For centuries, the Mesoamerican reef in the Ca...
#
# [498 rows x 42 columns]

# %%
tmp = tmp.sample(frac = 1)

# %%
unclear = tmp[tmp['gender_first_researcher_text'] == 'Unclear']
unclear = unclear.reset_index(drop = True)

# %%
for i in unclear.index:
    #These articles don't mention any researchers
    print(unclear.loc[i, 'article_link'])
# Out:
# https://news.mit.edu/2019/qs-world-university-rankings-0226
# https://news.mit.edu/2019/graduate-engineering-business-programs-top-rankings-us-news-0312

# %%
#drop the articles that don't mention any researchers
tmp = tmp[tmp['gender_first_researcher_text']!='Unclear']
tmp
# Out:
#         article_id                                      article_title  \
# 470       yale_267            A tool for identifying phases of matter
# 822   columbia_179  Combating Climate Change With Artificial Intel...
# 561    harvard_150                        Physics, real and fictional
# 872   columbia_221  It’s Raining on the Greenland Ice. In the Winter.
# 570    harvard_159                            A clue to biodiversity?
# ..             ...                                                ...
# 253  princeton_178  Data science tool that reveals molecular cause...
# 78         mit_772   IDEAS challenge showcases social ventures at MIT
# 44        mit_1298  Ruth Lehmann elected as director of Whitehead ...
# 517       yale_346  New studies confirm existence of galaxies with...
# 148        mit_842  Exercises in amazement: Discovering deep learning
#
#                                           article_link  \
# 470  https://news.yale.edu/2019/06/19/tool-identify...
# 822  https://science.fas.columbia.edu/news/combatin...
# 561  https://news.harvard.edu/gazette/story/2019/11...
# 872  https://science.fas.columbia.edu/news/its-rain...
# 570  https://news.harvard.edu/gazette/story/2019/10...
# ..                                                 ...
# 253  https://www.princeton.edu/news/2019/02/28/data...
# 78   https://news.mit.edu/2019/ideas-challenge-soci...
# 44   https://news.mit.edu/2019/ruth-lehmann-elected...
# 517  https://news.yale.edu/2019/03/29/new-studies-c...
# 148  https://news.mit.edu/2019/discovering-deep-lea...
#
#                 article_date gender_first_researcher  num_women_mentioned  \
# 470            June 19, 2019                       1                  0.0
# 822             June 5, 2019                       2                  2.0
# 561        November 14, 2019                       1                  1.0
# 872            March 7, 2019                       2                  1.0
# 570         October 31, 2019                       1                  0.0
# ..                       ...                     ...                  ...
# 253  Feb. 28, 2019 1:19 p.m.                       2                  2.0
# 78            April 30, 2019                       1                  3.0
# 44        September 19, 2019                       2                  2.0
# 517           March 29, 2019                       1                  1.0
# 148           March 15, 2019                       1                  2.0
#
#      num_men_mentioned num_others_mentioned  \
# 470                6.0                    0
# 822                0.0                    0
# 561                3.0                    0
# 872                2.0                    0
# 570                3.0                    0
# ..                 ...                  ...
# 253                1.0                    0
# 78                 1.0                    0
# 44                 5.0                    0
# 517                1.0                    0
# 148                3.0                    0
#
#                                         image_alt_text  \
# 470                             Torus topology diagram
# 822                                                NaN
# 561                                   Levitating frog.
# 872                                                NaN
# 570  Heliconius xanthocles butterfly illustration w...
# ..                                                 ...
# 253                     Visualization of gene activity
# 78   Kate Trimble (left), associate dean and senior...
# 44   Ruth Lehmann, a world-renowned developmental a...
# 517                          A photo of the DF2 galaxy
# 148  More than 300 people enrolled in 6.S19, an IAP...
#
#                                         image_captions  ...  \
# 470                                (© stock.adobe.com)  ...
# 822  Maria Uriarte, left, and Tian Zheng bring ecol...  ...
# 561  Photo illustration by Judy Blomquist/Harvard S...  ...
# 872  Increasing rainfall over the Greenland ice she...  ...
# 570  An analysis of 20 butterfly genomes found evid...  ...
# ..                                                 ...  ...
# 253  Princeton researchers created a data science t...  ...
# 78             Kate Trimble (left), associate dean ...  ...
# 44             Ruth Lehmann, a world-renowned devel...  ...
# 517  A photo of the DF2 galaxy (Image credit: NASA,...  ...
# 148            More than 300 people enrolled in 6.S...  ...
#
#                    OLD_article_text_w_main_img_caption needs_recode  \
# 470                                                NaN          NaN
# 822                                                NaN          NaN
# 561                                                NaN          NaN
# 872                                                NaN          NaN
# 570                                                NaN          NaN
# ..                                                 ...          ...
# 253  Princeton University researchers are gaining n...        False
# 78                                                 NaN          NaN
# 44                                                 NaN          NaN
# 517                                                NaN          NaN
# 148                                                NaN          NaN
#
#                                           url_redirect           PAGE_TYPE  \
# 470  https://news.yale.edu/2019/06/19/tool-identify...  div story clearfix
# 822                                                NaN                 NaN
# 561                                                NaN                 NaN
# 872                                                NaN                 NaN
# 570                                                NaN                 NaN
# ..                                                 ...                 ...
# 253                                                NaN                 NaN
# 78                                                 NaN                 NaN
# 44                                                 NaN                 NaN
# 517  https://news.yale.edu/2019/03/29/new-studies-c...  div story clearfix
# 148                                                NaN                 NaN
#
#     source in_og article_id.1 recode rater_recode_intials  \
# 470    old   NaN          NaN    NaN                  NaN
# 822    NaN   NaN          NaN    NaN                  NaN
# 561    NaN   NaN  harvard_150    0.0                   DP
# 872    NaN   NaN          NaN    NaN                  NaN
# 570    NaN   NaN  harvard_159    0.0                   DP
# ..     ...   ...          ...    ...                  ...
# 253    NaN   NaN          NaN    NaN                  NaN
# 78     NaN   NaN          NaN    NaN                  NaN
# 44     NaN   NaN          NaN    NaN                  NaN
# 517    old   NaN          NaN    NaN                  NaN
# 148    NaN   NaN          NaN    NaN                  NaN
#
#                                     new_article_text.1
# 470                                                NaN
# 822  Thinking about what could lie ahead when clima...
# 561                                                NaN
# 872  Rainy weather is becoming increasingly common ...
# 570                                                NaN
# ..                                                 ...
# 253                                                NaN
# 78                                                 NaN
# 44                                                 NaN
# 517                                                NaN
# 148                                                NaN
#
# [496 rows x 42 columns]

# %%
tmp.uni.value_counts()
# Out:
# harvard      100
# princeton    100
# yale          99
# columbia      99
# mit           98
# Name: uni, dtype: int64

# %%
tmp.gender_first_researcher_text.value_counts()
# Out:
# Man      341
# Woman    155
# Name: gender_first_researcher_text, dtype: int64

# %%
pd.crosstab(tmp.gender_first_researcher_text, tmp.uni, margins = True).T
# Out:
# gender_first_researcher_text  Man  Woman  All
# uni
# columbia                       71     28   99
# harvard                        71     29  100
# mit                            72     26   98
# princeton                      68     32  100
# yale                           59     40   99
# All                           341    155  496

# %%
tmp.columns
# Out:
# Index(['article_id', 'article_title', 'article_link', 'article_date',
#        'gender_first_researcher', 'num_women_mentioned', 'num_men_mentioned',
#        'num_others_mentioned', 'image_alt_text', 'image_captions',
#        'photo_filename', 'first_researcher_pictured',
#        'num_male_researchers_pictured', 'num_female_researchers_pictured',
#        'num_other_researchers_pictured', 'num_women_pictured',
#        'num_men_pictured', 'num_other_people_pictured', 'rater_initials',
#        'comments', 'image_location', 'image_links', 'article_date_scrape',
#        'article_title_scrape', 'article_text', 'num_pics',
#        'gender_first_researcher_text', 'num_first_res_pics',
#        'num_female_res_pics', 'num_male_res_pics', 'total_people_mentioned',
#        'uni', 'OLD_article_text_w_main_img_caption', 'needs_recode',
#        'url_redirect', 'PAGE_TYPE', 'source', 'in_og', 'article_id.1',
#        'recode', 'rater_recode_intials', 'new_article_text.1'],
#       dtype='object')

# %%
keep_cols = ['article_id', 'article_title', 'article_link',
            'article_date', 'gender_first_researcher',
             'gender_first_researcher_text',
            'uni', 'article_text']
keep_cols.extend([c for c in tmp.columns.to_list() if '_mentioned' in c or '_pictured' in c or '_pics' in c])

# %%
keep_cols
# Out:
# ['article_id',
#  'article_title',
#  'article_link',
#  'article_date',
#  'gender_first_researcher',
#  'gender_first_researcher_text',
#  'uni',
#  'article_text',
#  'num_women_mentioned',
#  'num_men_mentioned',
#  'num_others_mentioned',
#  'first_researcher_pictured',
#  'num_male_researchers_pictured',
#  'num_female_researchers_pictured',
#  'num_other_researchers_pictured',
#  'num_women_pictured',
#  'num_men_pictured',
#  'num_other_people_pictured',
#  'num_pics',
#  'num_first_res_pics',
#  'num_female_res_pics',
#  'num_male_res_pics',
#  'total_people_mentioned']

# %%
tmp_condensed = tmp[keep_cols]
tmp_condensed.to_csv(f"{data_io.DATA}article_data_cleaned.csv", index = False, encoding = 'utf-8-sig')
